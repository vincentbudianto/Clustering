# %% [markdown]
# # Tugas Besar 2 IF3270 - Machine Learning
# ------------------------------------------
# ##### NIM/Nama  : 13517014/Yoel Susanto | 13517065/Andrian Cedric | 13517131/Jan Meyer Saragih | 13517137/Vincent Budianto
# ##### Nama file : Tubes2_13517014_KMeans.ipynb
# ##### Topik     : Implementasi modul K-Means Clustering
# ##### Tanggal   : 19 April 2020
# ------------------------------------------

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics.cluster import fowlkes_mallows_score
from src.kmeans import *

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading Iris Dataset

# %%
iris = datasets.load_iris()
data = iris.data
target = iris.target

# %% [markdown]
# ## Sklearn K-Means

# %%
km = KMeans(n_clusters = 3, n_jobs = 4, random_state=25)
km.fit(data)
sklearn_target = km.labels_
print('fowlkes mallows score:', fowlkes_mallows_score(target, sklearn_target))
print('     silhouette score:', silhouette_score(data, sklearn_target, metric='euclidean'))
# Out:
# fowlkes mallows score: 0.8208080729114153
#      silhouette score: 0.5528190123564091

# %% [markdown]
# ## Implemented K-Means

# %%
clusters = kmeans(n_clusters=3)
clusters.fit(data)
implemented_target = clusters.labels
print('fowlkes mallows score:', fowlkes_mallows_score(target, implemented_target))
print('     silhouette score:', silhouette_score(data, implemented_target, metric='euclidean'))
# Out:
# [[7.6 3.  6.6 2.1]
#  [6.3 3.3 6.  2.5]
#  [6.  2.2 4.  1. ]]
# [[6.85       3.07368421 5.74210526 2.07105263]
#  [5.9016129  2.7483871  4.39354839 1.43387097]
#  [5.006      3.428      1.462      0.246     ]]
# fowlkes mallows score: 0.8208080729114153
#      silhouette score: 0.5528190123564091

# %% [markdown]
# ## Iris Dataset Visualization

# %%
fig, axes = plt.subplots(1, 3, figsize=(24,8))

# Actual dataset
axes[0].scatter(data[:,0], data[:,1], c=target, cmap='gist_rainbow', edgecolor='k', s=150)
axes[0].set_title('Actual Dataset', fontsize=18)
axes[0].set_xlabel('Sepal Length', fontsize=18)
axes[0].set_ylabel('Sepal Width', fontsize=18)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

# Sklearn K-Means dataset
axes[1].scatter(data[:,0], data[:,1], c=sklearn_target, cmap='brg', edgecolor='k', s=150)
axes[1].set_title('Sklearn K-Means', fontsize=18)
axes[1].set_xlabel('Sepal Length', fontsize=18)
axes[1].set_ylabel('Sepal Width', fontsize=18)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

# Implemented K-Means dataset
axes[2].scatter(data[:,0], data[:,1], c=implemented_target, cmap='rainbow', edgecolor='k', s=150)
axes[2].set_title('Implemented K-Means', fontsize=18)
axes[2].set_xlabel('Sepal Length', fontsize=18)
axes[2].set_ylabel('Sepal Width', fontsize=18)
axes[2].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: (1, None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4231             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4232                 colors = mcolors.to_rgba_array(c)
#    4233                 n_elem = colors.shape[0]
#
# ...

# %%
figPetal, axesPetal = plt.subplots(1, 3, figsize=(24,8))

# Actual dataset
axesPetal[0].scatter(data[:,2], data[:,3], c=target, cmap='gist_rainbow', edgecolor='k', s=150)
axesPetal[0].set_title('Actual Dataset', fontsize=18)
axesPetal[0].set_xlabel('Petal Length', fontsize=18)
axesPetal[0].set_ylabel('Petal Width', fontsize=18)
axesPetal[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

# Sklearn K-Means dataset
axesPetal[1].scatter(data[:,2], data[:,3], c=sklearn_target, cmap='brg', edgecolor='k', s=150)
axesPetal[1].set_title('Sklearn K-Means', fontsize=18)
axesPetal[1].set_xlabel('Petal Length', fontsize=18)
axesPetal[1].set_ylabel('Petal Width', fontsize=18)
axesPetal[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

# Implemented K-Means dataset
axesPetal[2].scatter(data[:,2], data[:,3], c=implemented_target, cmap='rainbow', edgecolor='k', s=150)
axesPetal[2].set_title('Implemented K-Means', fontsize=18)
axesPetal[2].set_xlabel('Petal Length', fontsize=18)
axesPetal[2].set_ylabel('Petal Width', fontsize=18)
axesPetal[2].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-90452eaa7f68> in <module>
#       2
#       3 # Actual dataset
# ----> 4 axesPetal[0].scatter(data[:,2], data[:,3], c=target, cmap='gist_rainbow', edgecolor='k', s=150)
#       5 axesPetal[0].set_title('Actual Dataset', fontsize=18)
#       6 axesPetal[0].set_xlabel('Petal Length', fontsize=18)
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
data, target = datasets.make_blobs(centers=3, n_samples=1500)

fig = plt.figure(figsize=(12,8))
plt.scatter(data[:,0], data[:,1], c=target)
plt.title('Cluster')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("Initial centers in black, final centers in red")
plt.scatter(data[:, 0], data[:, 1], marker='.', c=target)
plt.scatter(clusters.centroids[:, 0], clusters.centroids[:, 1], c='r')
plt.scatter(clusters.intial_centroids[:, 0], clusters.intial_centroids[:, 1], c='k')
plt.show()
